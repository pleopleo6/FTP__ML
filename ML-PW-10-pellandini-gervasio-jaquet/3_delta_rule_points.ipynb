# %% [markdown]
# # Delta Rule
# The Delta Rule is a gradient descent approximator that can be used to find the weight values of a Perceptron. The Delta Rule minimizes an error function (tipically $E=\frac{1}{2}(y - t)^{2}$) by adapting the weight connections in small steps. The step length is defined by the learning rate $\alpha$. In this notebook you will explore the classification capabilities of a single Perceptron by using the delta rule. You will start by setting the connection weights by hand for a simple problem, and then you will apply the delta rule for the same problem, and others.

# %% [markdown]
# ## Loading the packages

# %%
import numpy as np
from ipywidgets import interact, widgets

from matplotlib import animation

# %% [markdown]
# ## Loading the Perceptron code
# In order to the make this nothebook smaller, some of the functions (activation functions, and some of the code allowing the visualization of the results) was implemented in a separate python file. You are free to open it if needed.

# %%
import perceptron as pt

# %% [markdown]
# ## The Dataset
# The following script allows you to create a 2D dataset by using the mouse. First click to add points belonging to class A (blue), and then click to add points belonging to class B (red). You can create as many points as you desire. The final dataset will contain hence three values per point: x coordinate (-1 ≤ x ≤ 1), y coordinate (-1 ≤ y ≤ 1) and the class ∈ {1,-1}.

# %% [markdown]
# ### Blue points first

# %%
# Install ipympl if it's not installed yet:
#!pip install ipympl

# %%
# %matplotlib widget
import matplotlib.pyplot as pl

fig = pl.figure(figsize=(6,6))
pl.title("Input Dataset")
pl.xlim((-1.2,1.2))
pl.ylim((-1.2,1.2))

dataset = []

def onclick_blue(event):
    global dataset
    if event.xdata is not None and event.ydata is not None:
        cx = event.xdata
        cy = event.ydata
        dataset.append((cx, cy, 1))
        pl.scatter(cx, cy, c='b', s=100, lw=0)
        pl.grid(True)
        pl.draw()

cid = fig.canvas.mpl_connect('button_press_event', onclick_blue)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig.canvas.mpl_disconnect(cid)

# %% [markdown]
# ### Then, red points

# %%
# %matplotlib notebook

fig = pl.figure(figsize=(6,6))
for i in np.arange(len(dataset)):
    pl.scatter(dataset[i][0], dataset[i][1], c='b', s=100, lw=0)

pl.title("Input Dataset")
pl.xlim((-1.2,1.2))
pl.ylim((-1.2,1.2))

def onclick_red(event):
    global dataset
    cx = event.xdata
    cy = event.ydata
    dataset.append((cx, cy, -1))
    
    pl.scatter(cx, cy, c='r', s=100, lw=0)
    pl.grid(True)

fig.canvas.mpl_disconnect(onclick_blue)
cid = fig.canvas.mpl_connect('button_press_event', onclick_red)
# Out:
# Warning: Cannot change to a different GUI toolkit: notebook. Using widget instead.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig.canvas.mpl_disconnect(cid)

# %% [markdown]
# This is the dataset you just created. Check that there are no NaNs in the third column. Create once again the dataset if necessary

# %%
dataset
# Out:
# [(0.8490322580645162, -0.9675324675324674, 1),
#  (0.8903225806451616, -1.087012987012987, 1),
#  (0.5703225806451613, -1.0662337662337662, 1),
#  (0.31741935483870987, -0.9155844155844154, 1),
#  (0.059354838709677615, -0.9675324675324674, 1),
#  (-0.20387096774193525, -1.0194805194805192, 1),
#  (-0.5548387096774192, -1.0194805194805192, 1),
#  (-0.8180645161290321, -0.983116883116883, 1),
#  (-0.7974193548387095, -0.8272727272727272, 1),
#  (-0.6425806451612902, -0.7493506493506492, 1),
#  (-0.42064516129032237, -0.718181818181818, 1),
#  (-0.3329032258064515, -0.7805194805194804, 1),
#  (-0.2503225806451612, -0.8428571428571427, 1),
#  (-0.07999999999999985, -0.8636363636363635, 1),
#  (0.054193548387097, -0.8064935064935064, 1),
#  (0.07483870967741946, -0.7233766233766232, 1),
#  (0.03870967741935494, -0.6350649350649349, 1),
#  (-0.07483870967741924, -0.5155844155844154, 1),
#  (-0.09548387096774169, -0.42207792207792183, 1),
#  (-0.07483870967741924, -0.3701298701298701, 1),
#  (0.002580645161290418, -0.3285714285714285, 1),
#  (0.1470967741935485, -0.28181818181818175, 1),
#  (0.19354838709677447, -0.28701298701298694, 1),
#  (0.25548387096774205, -0.3181818181818181, 1),
#  (0.2709677419354841, -0.4428571428571426, 1),
#  (0.27612903225806473, -0.6142857142857141, 1),
#  (0.3638709677419356, -0.7597402597402596, 1),
#  (0.6219354838709679, -0.8272727272727272, 1),
#  (0.8490322580645162, -0.744155844155844, 1),
#  (0.8851612903225807, -0.6038961038961037, 1),
#  (0.854193548387097, -0.5207792207792206, 1),
#  (0.6838709677419357, -0.4376623376623374, 1),
#  (0.5187096774193551, -0.4584415584415582, 1),
#  (0.4722580645161294, -0.4480519480519478, 1),
#  (0.487741935483871, -0.29220779220779214, 1),
#  (0.5290322580645164, -0.2038961038961038, 1),
#  (0.854193548387097, -0.10519480519480506, 1),
#  (0.8851612903225807, -0.0012987012987011326, 1),
#  (0.8800000000000003, 0.08701298701298721, 1),
#  (0.8851612903225807, 0.21168831168831193, 1),
#  (0.8903225806451616, 0.32077922077922083, 1),
#  (0.9212903225806452, 0.42467532467532476, 1),
#  (0.9470967741935485, 0.5441558441558443, 1),
#  (0.9419354838709677, 0.5909090909090913, 1),
#  (0.9367741935483873, 0.6584415584415586, 1),
#  (0.9212903225806452, 0.7103896103896106, 1),
#  (0.8903225806451616, 0.7155844155844155, 1),
#  (0.8129032258064517, 0.6948051948051948, 1),
#  (0.6477419354838712, 0.6324675324675324, 1),
#  (0.6167741935483875, 0.5441558441558443, 1),
#  (0.5651612903225809, 0.46103896103896114, 1),
#  (0.5290322580645164, 0.3987012987012988, 1),
#  (0.43096774193548404, 0.2844155844155847, 1),
#  (0.21935483870967754, 0.18051948051948075, 1),
#  (0.1522580645161291, 0.12857142857142878, 1),
#  (0.1729032258064518, 0.04025974025974044, 1),
#  (0.28129032258064535, -0.02207792207792192, 1),
#  (0.415483870967742, -0.027272727272727115, 1),
#  (0.5548387096774197, 0.019480519480519654, 1),
#  (0.6477419354838712, 0.08701298701298721, 1),
#  (0.6374193548387099, 0.2376623376623379, 1),
#  (0.6477419354838712, 0.325974025974026, 1),
#  (0.7045161290322581, 0.41948051948051956, 1),
#  (0.8025806451612905, 0.5337662337662339, 1),
#  (0.8180645161290325, 0.5805194805194809, 1),
#  (0.9264516129032261, 0.8090909090909091, 1),
#  (0.9935483870967743, 0.907792207792208, 1),
#  (1.0658064516129033, 1.0064935064935066, 1),
#  (1.0916129032258066, 0.964935064935065, 1),
#  (1.0864516129032258, 0.7363636363636363, 1),
#  (1.055483870967742, 0.5649350649350651, 1),
#  (1.0503225806451613, 0.3831168831168832, 1),
#  (1.0451612903225809, 0.21168831168831193, 1),
#  (1.0451612903225809, 0.04025974025974044, 1),
#  (1.0348387096774196, -0.09999999999999987, 1),
#  (1.04, -0.3181818181818181, 1),
#  (1.055483870967742, -0.531168831168831, 1),
#  (1.0451612903225809, -0.6506493506493505, 1),
#  (1.0296774193548388, -0.8844155844155842, 1),
#  (1.0193548387096776, -0.931168831168831, 1),
#  (0.7612903225806451, -0.77012987012987, 1),
#  (0.6270967741935487, -0.6870129870129869, 1),
#  (0.56, -0.6402597402597401, 1),
#  (0.4258064516129032, -0.5623376623376621, 1),
#  (0.3277419354838711, -0.5207792207792206, 1),
#  (0.30709677419354864, -0.25064935064935057, 1),
#  (0.40000000000000013, -0.209090909090909, 1),
#  (0.5290322580645164, -0.22467532467532458, 1),
#  (0.6941935483870969, -0.25584415584415576, 1),
#  (0.781935483870968, -0.27662337662337655, 1),
#  (0.8903225806451616, -0.3181818181818181, 1),
#  (0.895483870967742, -0.3597402597402597, 1),
#  (0.08000000000000007, -0.4584415584415582, 1),
#  (0.13161290322580665, -0.5363636363636362, 1),
#  (0.18322580645161302, -0.6142857142857141, 1),
#  (0.19870967741935508, -0.7493506493506492, 1),
#  (0.19870967741935508, -0.8428571428571427, 1),
#  (0.21419354838709692, -1.0142857142857142, 1),
#  (0.2348387096774196, -1.0506493506493504, 1),
#  (0.34838709677419377, -1.0142857142857142, 1),
#  (0.4619354838709677, -0.9467532467532466, 1),
#  (0.6064516129032258, -0.905194805194805, 1),
#  (-0.3638709677419354, -0.8948051948051946, 1),
#  (-0.3741935483870966, -1.0454545454545454, 1),
#  (-0.5909677419354837, -1.087012987012987, 1),
#  (-0.8696774193548386, -1.0246753246753246, 1),
#  (-1.169032258064516, -1.0038961038961038, 1),
#  (-0.5651612903225804, -0.9519480519480518, 1),
#  (-0.6064516129032257, -0.848051948051948, 1),
#  (-0.32774193548387087, -0.7285714285714284, 1),
#  (-0.20903225806451586, -0.6766233766233765, 1),
#  (-0.20387096774193525, -0.5883116883116881, 1),
#  (-0.25548387096774183, 0.8150974025974027, -1),
#  (-0.4877419354838708, 0.2540584415584417, -1),
#  (-0.6683870967741934, 0.14496753246753258, -1),
#  (-0.7406451612903224, 0.046266233766233844, -1),
#  (-0.936774193548387, 0.2540584415584417, -1),
#  (-0.9058064516129031, 0.3891233766233768, -1),
#  (-0.6116129032258063, 0.48782467532467555, -1),
#  (-0.19870967741935464, 0.5449675324675325, -1),
#  (-0.10064516129032253, 0.5761363636363637, -1),
#  (0.08000000000000007, 0.8358766233766235, -1),
#  (0.16258064516129056, 0.8306818181818185, -1),
#  (0.14193548387096788, 0.6073051948051948, -1),
#  (0.054193548387097, 0.48782467532467555, -1),
#  (-0.14193548387096766, 0.34237012987013005, -1),
#  (-0.23483870967741916, 0.18133116883116895, -1),
#  (-0.3380645161290321, 0.061850649350649434, -1),
#  (-0.44645161290322566, -0.07321428571428545, -1),
#  (-0.5806451612903225, -0.2758116883116881, -1),
#  (-0.6477419354838708, -0.35892857142857126, -1),
#  (-0.7716129032258063, -0.4212662337662336, -1),
#  (-0.9264516129032256, -0.431655844155844, -1),
#  (-1.0761290322580643, -0.4939935064935064, -1),
#  (-1.0503225806451613, -0.6550324675324674, -1),
#  (-1.0348387096774192, -0.7693181818181817, -1),
#  (-0.8851612903225805, -0.5771103896103894, -1),
#  (-0.8541935483870966, -0.5303571428571427, -1),
#  (-0.9832258064516127, -0.34853896103896087, -1),
#  (-1.0554838709677417, -0.25503246753246733, -1),
#  (-1.081290322580645, -0.1459415584415582, -1),
#  (-1.0193548387096771, 0.05146103896103904, -1),
#  (-0.9780645161290321, 0.06704545454545463, -1),
#  (-0.936774193548387, 0.025487012987013058, -1),
#  (-0.9264516129032256, -0.08879870129870104, -1),
#  (-0.921290322580645, -0.1355519480519478, -1),
#  (-0.8645161290322579, -0.1459415584415582, -1),
#  (-0.7406451612903224, -0.13035714285714262, -1),
#  (-0.689032258064516, -0.12516233766233742, -1),
#  (-0.601290322580645, -0.11477272727272703, -1),
#  (-0.544516129032258, -0.11477272727272703, -1),
#  (-0.4825806451612902, -0.11996753246753222, -1),
#  (-0.425806451612903, -0.11477272727272703, -1),
#  (-0.38451612903225785, -0.09918831168831144, -1),
#  (-0.3999999999999999, 0.009902597402597468, -1),
#  (-0.4516129032258063, 0.13457792207792219, -1),
#  (-0.44645161290322566, 0.20730519480519494, -1),
#  (-0.41032258064516114, 0.2696428571428573, -1),
#  (-0.38451612903225785, 0.3995129870129872, -1),
#  (-0.3948387096774193, 0.5189935064935067, -1),
#  (-0.41032258064516114, 0.5969155844155845, -1),
#  (-0.44129032258064504, 0.5969155844155845, -1),
#  (-0.5651612903225804, 0.49821428571428594, -1),
#  (-0.6064516129032257, 0.4306818181818184, -1),
#  (-0.6529032258064514, 0.36314935064935083, -1),
#  (-0.745806451612903, 0.30600649350649367, -1),
#  (-0.8025806451612901, 0.31639610389610406, -1),
#  (-0.8283870967741934, 0.35275974025974044, -1),
#  (-0.8799999999999998, 0.4099025974025976, -1),
#  (-0.9987096774193547, 0.47224025974025974, -1),
#  (-1.1070967741935482, 0.5501623376623379, -1),
#  (-1.0916129032258062, 0.5969155844155845, -1),
#  (-1.024516129032258, 0.6748376623376626, -1),
#  (-0.9522580645161288, 0.7787337662337666, -1),
#  (-0.9161290322580643, 0.8150974025974027, -1),
#  (-0.9316129032258063, 0.986525974025974, -1),
#  (-1.009032258064516, 1.0696428571428571, -1),
#  (-0.6787096774193546, 1.0644480519480521, -1),
#  (-0.5341935483870965, 1.0280844155844155, -1),
#  (-0.5599999999999998, 0.9034090909090913, -1),
#  (-0.6219354838709675, 0.7579545454545458, -1),
#  (-0.6787096774193546, 0.6644480519480522, -1),
#  (-0.8438709677419354, 0.7527597402597404, -1),
#  (-0.7199999999999999, 0.9241883116883121, -1),
#  (-0.5187096774193547, 0.929383116883117, -1),
#  (-0.3329032258064515, 0.9086038961038962, -1),
#  (-0.3122580645161288, 0.8410714285714289, -1),
#  (-0.19354838709677402, 0.7787337662337666, -1),
#  (-0.09548387096774169, 0.7215909090909092, -1),
#  (-0.038709677419354716, 0.685227272727273, -1),
#  (-0.00774193548387081, 0.5657467532467533, -1),
#  (-0.0335483870967741, 0.4358766233766236, -1),
#  (-0.05419354838709656, 0.31639610389610406, -1),
#  (-0.07483870967741924, 0.20211038961038974, -1),
#  (-0.1522580645161289, 0.08262987012987022, -1),
#  (-0.17806451612903218, -0.016071428571428514, -1),
#  (0.002580645161290418, 0.2800324675324677, -1),
#  (0.10580645161290336, 0.36834415584415603, -1),
#  (0.16774193548387117, 0.49821428571428594, -1),
#  (0.2658064516129033, 0.7163961038961042, -1),
#  (0.2658064516129033, 0.7735389610389611, -1),
#  (0.4825806451612906, 0.8410714285714289, -1),
#  (0.4464516129032261, 0.9709415584415586, -1),
#  (0.5445161290322584, 1.0176948051948052, -1),
#  (0.6270967741935487, 1.0696428571428571, -1),
#  (0.7354838709677423, 1.085227272727273, -1),
#  (0.709677419354839, 1.0228896103896106, -1),
#  (0.4361290322580649, 0.9605519480519482, -1),
#  (0.2916129032258066, 1.0228896103896106, -1),
#  (0.22967741935483899, 1.0592532467532467, -1),
#  (0.11612903225806459, 1.0748376623376625, -1),
#  (0.04387096774193555, 1.033279220779221, -1),
#  (0.054193548387097, 0.9449675324675324, -1),
#  (-0.05935483870967717, 0.9241883116883121, -1),
#  (-0.2141935483870967, 0.9761363636363636, -1),
#  (-0.23999999999999977, 1.0592532467532467, -1),
#  (-0.29161290322580635, 1.1008116883116883, -1),
#  (-0.3741935483870966, 1.085227272727273, -1),
#  (-0.5083870967741935, 0.9449675324675324, -1),
#  (-0.4825806451612902, 0.8410714285714289, -1),
#  (-0.5135483870967741, 0.7060064935064938, -1),
#  (-0.8541935483870966, 0.6748376623376626, -1),
#  (-0.8593548387096772, 0.5501623376623379, -1),
#  (0.3793548387096777, -0.6030844155844154, -1),
#  (0.6993548387096777, -0.5407467532467531, -1),
#  (0.7045161290322581, -0.026461038961038907, -1),
#  (-0.5548387096774192, 0.2592532467532469, -1),
#  (-0.5496774193548386, -0.166720779220779, -1),
#  (-0.5548387096774192, -0.4212662337662336, -1),
#  (-0.7199999999999999, -0.5719155844155842, -1),
#  (-0.369032258064516, -0.40568181818181803, -1),
#  (-0.3741935483870966, -0.24464285714285694, -1),
#  (-0.3329032258064515, -0.07840909090909065, -1)]

# %% [markdown]
# ## Finding the weights by hand
# In this section you should try to find the set of weights that allows a Perceptron to separate the two classes you previously defined. Use the sliders to modify the value of each one of the connections and the bias of the Perceptron while trying to separate the two classes (blue and red). The curve on the right represents the classification error (MSE). If the modifications you provide improve the classification, you should see the error decreasing.

# %% [raw]
#             ______________
#            /              \
# x __w_x__ j                l
#   _______ | f_act(I.W + b) |------ output
# y   w_y   l                j
#            \______________/
# Where:
# x = input x
# y = input y
# b = bias
# f_act = activation function
# I = vector of inputs
# W = vector of weights

# %%
plotter = pt.PerceptronPlotter2D(data=np.asarray(dataset))

# %%
# %matplotlib inline
_= interact(plotter.plot_interactive, **plotter.controls)
# Out:
# interactive(children=(FloatSlider(value=0.5, description='Weight x:', max=2.0, min=-2.0, step=0.01), FloatSlid…

# %% [markdown]
# ## The Delta Rule
# In the following step we propose to solve the classification problem you defined by using the delta-rule algorithm. Look at the code in compute_delta_w and try to understand it.

# %% [raw]
#             ______________
#            /              \
# x __w_x__ j                l
#   _______ | f_act(I.W + b) |------ output
# y   w_y   l                j
#            \______________/
# Where:
# x = input x
# y = input y
# b = bias
# f_act = activation function
# I = vector of inputs
# W = vector of weights

# %% [markdown]
# $$ neta = (x * w\_x) + (y * w\_y) + b$$
# $$ output = f\_act(neta) $$
# $$ \Delta w\_x = \alpha * (target - output) * f\_act'(neta) * x $$
# $$ \Delta w\_y = \alpha * (target - output) * f\_act'(neta) * y $$
# $$ \Delta b = \alpha * (target - output) * f\_act'(neta) $$

# %%
def compute_delta_w(inputs, weights, bias, targets, alpha, activation_function):
    neta = np.dot(inputs, weights) + bias
    output, d_output = activation_function(neta)
    error = targets - output
    d_w_x = alpha * error * d_output * inputs[:,0]
    d_w_y = alpha * error * d_output * inputs[:,1]
    d_b = alpha * error * d_output
    return [d_w_x, d_w_y, d_b]

# %% [markdown]
# ## Batch learning
# When you launch the cell, the weights and the bias are initialized at random, and the algorithm perform some iterations (NUMBER_OF_EPOCHS) doing the following:
# +  for each point in the dataset, compute the modifications ( Δw ) to be done at each parameter in order to minimize the error function
# + sum up all the modifications -> batch policy
# + modify the weights and bias of the perceptron
#
# The cell records the effects of the modifications performed in a video. Therefore, you can visualize the learning process afterwards.

# %%
# %matplotlib inline

inputs = np.asarray(dataset)[:,0:2]
targets = np.asarray(dataset)[:,2]
weights = np.random.normal(size=2)
bias = np.random.normal(size=1)
activation_function = pt.htan

ALPHA = 0.1
NUMBER_OF_EPOCHS = 30

fig = pl.figure(figsize=(12, 4))
plotter = pt.PerceptronPlotter2D(data=np.asarray(dataset))
plotter.init_animation()

def run_epoch_batch(i, alpha, inputs, weights, bias, targets, activation_function):
    d_w_x, d_w_y, d_b = compute_delta_w(inputs, weights, bias, targets, ALPHA, activation_function)
    weights += np.array([np.sum(d_w_x), np.sum(d_w_y)])
    bias += np.sum(d_b)
    
    return plotter.data2animation(i, inputs, weights, bias, targets, activation_function)

SHOW_VIDEO = False       # change this flag if you are unable to see the video
if SHOW_VIDEO:
    anim = animation.FuncAnimation(fig, run_epoch_batch, fargs=(ALPHA, inputs, weights, bias, targets, activation_function), frames=NUMBER_OF_EPOCHS, interval=20, blit=True)
    pt.display_animation(anim)
else:
    for i in np.arange(NUMBER_OF_EPOCHS):
        run_epoch_batch(i, ALPHA, inputs, weights, bias, targets, activation_function)

# %% [markdown]
# ## Exercise
# You are free to modify the learning rate (ALPHA) and the number of iterations (NUMBER_OF_EPOCHS).
#
# Try different 2D classification problems and observe the behaviour of the algorithm in terms of:
# - Learning rate needed
# - Convergence speed
# - Oscillations
#
# Bare in mind that, in the current implementation, the parameters (weights and bias) are initialized randomly every time you launch the cell.
#
# Create dataset as shown and perform the following tests:
#
# 1. What happens if the boundaries between both classes are well defined?
# ![separable](separable.png)
#
# 2. What happens if the classes overlap? What could you say about oscillations in the error signal?
# ![overlapping](overlapping.png)
#
# 3. What happens if it is not possible to separate the classes with a single line? What could you say about local minima?
# ![non_separable](non_separable.png)
